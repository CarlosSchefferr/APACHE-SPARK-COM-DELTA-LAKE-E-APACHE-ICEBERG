# %% [markdown]
# # Cenário de Dados e Modelagem
#
# Este notebook descreve o cenário de e-commerce, a fonte de dados e o modelo relacional usado nas tabelas Delta e Iceberg.

# %% [markdown]
# ## Fonte de dados
#
# Fonte sugerida: [Olist Brazilian E-Commerce Dataset (Kaggle)](https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce).
#
# Para os exemplos de DML, usamos um conjunto reduzido de dados sintéticos compatíveis com o cenário.

# %% [markdown]
# ## Modelo ER
#
# ![Modelo ER](../docs/assets/er_model.svg)

# %% [markdown]
# ## DDL das tabelas de negócio

# %%
ddl_clientes = '''
CREATE TABLE clientes (
    cliente_id STRING,
    nome STRING,
    email STRING,
    cidade STRING
)
'''

ddl_pedidos = '''
CREATE TABLE pedidos (
    pedido_id STRING,
    cliente_id STRING,
    status STRING,
    valor_total DOUBLE,
    data_pedido DATE
)
'''

ddl_itens = '''
CREATE TABLE itens_pedido (
    item_id STRING,
    pedido_id STRING,
    produto STRING,
    quantidade INT,
    preco_unitario DOUBLE
)
'''

print(ddl_clientes)
print(ddl_pedidos)
print(ddl_itens)
